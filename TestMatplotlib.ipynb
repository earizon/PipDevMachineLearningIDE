# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
x1 = np.linspace(0, 2, 10)
plt.grid(False)
xpow2 = x1**2
xpow3 = [x**3 for x in x1]
plt.plot(x1, x1   , label='linear')
plt.plot(x1, x1**2, label='quadratic')
plt.plot(x1, xpow3, label='qubic')


plt.xlabel('x label')
plt.ylabel('y label')

plt.legend()

# %%
B=np    .load("/var/backups/tmp/l1.npy")
print(B.ravel())
print(B)
# Out:
# [29 22 23 27 26 28 20 22 26 26 29 24 21 23 21 26 25 26 25 24 29 20 20 28
#  22 21 24 27 27 26 26 27 27 23 23 25 21 26 29 23 29 22 21 26 26 22 23 25
#  29 29 27 28 21 23 22 26 26 22 27 25 26 26 27 27 22 24 21 22 25 24 20 26
#  26 20 29 22 29 25 20 27 28 28 24 28 29 27 28 26 21 29 28 24 22 24 26 25
#  24 20 22 29]
# [[29 22 23 27 26 28 20 22 26 26]
#  [29 24 21 23 21 26 25 26 25 24]
#  [29 20 20 28 22 21 24 27 27 26]
#  [26 27 27 23 23 25 21 26 29 23]
#  [29 22 21 26 26 22 23 25 29 29]
#  [27 28 21 23 22 26 26 22 27 25]
#  [26 26 27 27 22 24 21 22 25 24]
#  [20 26 26 20 29 22 29 25 20 27]
#  [28 28 24 28 29 27 28 26 21 29]
#  [28 24 22 24 26 25 24 20 22 29]]

# %%
import pandas as pd
df3 = pd.DataFrame (
  [
   ('City1', 99000, 100000, 101001 ),
   ('City2',109000, 200000, 201001 ),
   ('City3',209000, 300000, 301001 ),
  ],
  columns = ['NAME', '2009', '2010', '2011'],
  index   = ['I', 'II' , 'III'],
)

# plt.bar( x = df3['NAME'].values, height=df3[ ['2009', '2010', '2011'] ].values)
df3.plot(x='NAME' , y=['2009','2010','2011'], kind='bar')

# %%
print(df3[df3["2010"] > 100000])
print(df3[df3["2010"] > 100000][df3["2011"] > 250000])
# Out:
#       NAME    2009    2010    2011
# II   City2  109000  200000  201001
# III  City3  209000  300000  301001
#       NAME    2009    2010    2011
# III  City3  209000  300000  301001
# /home/earizon/.local/share/virtualenvs/PIPDEV_PythonMachineLearingIDE-QzPdtkzS/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
